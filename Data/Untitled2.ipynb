# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
books = pd.read_csv('OneDrive/Book Recommendation System/Data/BX-Books.csv', sep=";", error_bad_lines=False, encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 books = pd.read_csv('OneDrive/Book Recommendation System/Data/BX-Books.csv', sep=";", error_bad_lines=False, encoding='latin-1')
#
# NameError: name 'pd' is not defined

# %%
# !pip install mathplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement mathplotlib (from versions: none)
# ERROR: No matching distribution found for mathplotlib
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\ASUS\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
